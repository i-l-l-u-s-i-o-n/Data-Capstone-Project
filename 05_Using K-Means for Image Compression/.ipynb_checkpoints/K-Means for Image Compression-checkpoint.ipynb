# %% [markdown]
# <h2 align="center">Image Compression with K-means Clustering</h2>
# <h5 align="center">~ Shivam Shukla</h5>

# %% [markdown]
# Importing Libraries
# ---

# %%
from __future__ import print_function
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as image
plt.style.use("ggplot")

from skimage import io
from sklearn.cluster import KMeans

from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider
import ipywidgets as widgets

# %%
plt.rcParams['figure.figsize'] = (20, 12)

# %% [markdown]
# Data Preprocessing
# ---

# %%
img = io.imread('images/2.jpg')

# %%
ax = plt.axes(xticks=[],yticks=[])
ax.imshow(img)

# %%
img
# Out:
# Array([[[  0,  31, 137],
#         [  0,  31, 137],
#         [  0,  30, 136],
#         ...,
#         [106, 136, 196],
#         [104, 134, 194],
#         [101, 133, 192]],
#
#        [[  0,  31, 139],
#         [  0,  31, 139],
#         [  0,  30, 138],
#         ...,
#         [105, 136, 193],
#         [102, 132, 192],
#         [ 99, 131, 190]],
#
#        [[  0,  30, 138],
#         [  0,  30, 138],
#         [  0,  31, 139],
#         ...,
#         [103, 134, 191],
#         [101, 131, 191],
#         [ 98, 130, 189]],
#
#        ...,
#
#        [[201, 153,  68],
#         [201, 155,  69],
#         [203, 159,  72],
#         ...,
#         [133, 101,  62],
#         [167, 135,  96],
#         [147, 115,  76]],
#
#        [[199, 151,  66],
#         [202, 154,  69],
#         [205, 159,  73],
#         ...,
#         [127,  97,  59],
#         [139, 107,  69],
#         [132, 100,  62]],
#
#        [[203, 147,  62],
#         [209, 153,  68],
#         [212, 158,  72],
#         ...,
#         [127,  97,  59],
#         [145, 112,  77],
#         [144, 111,  78]]], dtype=uint8)

# %%
img.shape
# Out:
# (456, 615, 3)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()# Outputs the value between 0 and 1

# %%
img_scaled = scaler.fit_transform(img.reshape(-1,3)) # Reshaping image to [600*394(pixels) , 3(R,G,B)]

# %%
img_scaled.shape
# Out:
# (280440, 3)

# %%
img_scaled
# Out:
# array([[0.        , 0.125     , 0.5372549 ],
#        [0.        , 0.125     , 0.5372549 ],
#        [0.        , 0.12096774, 0.53333333],
#        ...,
#        [0.49803922, 0.39112903, 0.23137255],
#        [0.56862745, 0.4516129 , 0.30196078],
#        [0.56470588, 0.44758065, 0.30588235]])

# %% [markdown]
# Visualizing the Color Space using Point Clouds
# ---

# %%
from plot_utils import plot_utils

# %%
x = plot_utils(img_scaled,title="Original Image color space: over 16 Million colors")

# %%
x.colorSpace()

# %% [markdown]
# There is smooth transition from one color to another and we will try to reduce the diversity of the colors and let the color have the sharp transition from one color to another.

# %% [markdown]
# Visualizing the K-means Reduced Color Space
# ---

# %% [markdown]
# <a title="Incheol [CC BY-SA 4.0 (https://creativecommons.org/licenses/by-sa/4.0)], via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Kmeans_animation.gif"><img width="300" alt="Kmeans animation" src="https://upload.wikimedia.org/wikipedia/commons/d/d5/Kmeans_animation.gif"></a>
# <h5 align="center">Incheol [<a href="https://creativecommons.org/licenses/by-sa/4.0">CC BY-SA 4.0</a>], <a href="https://commons.wikimedia.org/wiki/File:Kmeans_animation.gif">via Wikimedia Commons</a></h5>

# %% [markdown]
# **K-means Algorithm**:
#
# 1. Initialization: Randomly sample $k$ colors from the input image. These are the initial $k$ means $\mu_1,\mu_2,...,\mu_k$.
#
#
# 2. For each pixel in the image, assign it to its nearest mean given by $$c^{(i)} := \textrm{argmin}_{j}\left \|x^{(i)} - \mu_j \right \|^2$$
#
#
# 3. Update the means using the pixel assignments from Step 2. $$\mu_j := \frac{\sum_{i}^{n}1\left \{c^{(i)} = j  \right \}x^{(i)}}{\sum_{i}^{n}1\left \{c^{(i)} = j  \right \}}$$
#
#
# 4. Repeat Steps 2 and 3 until convergence.

# %%
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
#  # We want to reduce the colors from 16 Million to only 16 colors as most of the colors are unused !!!!!

# %%
kmeans = MiniBatchKMeans(16)

# %%
kmeans.fit(img_scaled)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=16, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
 kmeans.cluster_centers_
# Out:
# array([[0.18246728, 0.42394238, 0.69609183],
#        [0.72070819, 0.55284272, 0.31785715],
#        [0.5216974 , 0.66999705, 0.81150883],
#        [0.45764251, 0.30080305, 0.17372642],
#        [0.53731582, 0.56745591, 0.56231225],
#        [0.12722715, 0.23262807, 0.27333108],
#        [0.61951067, 0.4066322 , 0.20698252],
#        [0.34894626, 0.52631311, 0.74566692],
#        [0.06319435, 0.32195386, 0.65666277],
#        [0.72420472, 0.70879822, 0.63913983],
#        [0.33428393, 0.37424348, 0.40993856],
#        [0.51481131, 0.44716066, 0.37714313],
#        [0.26949561, 0.20308607, 0.15708686],
#        [0.01723481, 0.19774067, 0.59531692],
#        [0.08756084, 0.09220583, 0.08850604],
#        [0.71015813, 0.62653072, 0.48847795]])

# %%
kmeans.predict(img_scaled)
# Out:
# array([13, 13, 13, ...,  3, 11, 11], dtype=int32)

# %%
new_16_colors =  kmeans.cluster_centers_[kmeans.predict(img_scaled)]

# %% [markdown]
# ## Now plotting these new 16 colors

# %%
y = plot_utils(img_scaled,colors=new_16_colors,title="Compressed Image : using only 16 colors")

# %%
y.colorSpace()

# %% [markdown]
# ## Saving image

# %% [markdown]
# ***original image size = 95.6 KB***
#
# ***compressed image size = 61.2 KB***

# %%
io.imsave('c.jpg',new_16_colors.reshape(img.shape))
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ### Here we can see the sharp transitions from one color to another as there are only 16 colors. Whereas using 16 M colors makes the transion much smoother! But as 16 <<<<< 16 million so we can achieve great compression and compression reatio is 1 million pixel.

# %% [markdown]
# K-means Image Compression with Interactive Controls
# ---

# %%
img_dir = "images/"

# %%
@interact
def color_compression(Image=os.listdir(img_dir), k = IntSlider(min=1,max=256,step=1,value=16,
                                                               continuous_update=False,
                                                              layout=dict(width='100%'))):
    
    input_img = io.imread(img_dir+Image)
    
    img_scaled = (input_img/255).reshape(-1,3)    # We can also use MinMax Scaler as we used above to get values between 0 and 1.
    
    
    kmeans = MiniBatchKMeans(k)
    
    kmeans.fit(img_scaled)
    
    compressed_image_array = kmeans.cluster_centers_[kmeans.predict(img_scaled)]
    
    compressed_image = compressed_image_array.reshape(input_img.shape)
    
    fig,(ax1,ax2) = plt.subplots(1,2)
    
    fig.suptitle("K-Means Image Compression",fontsize=20)
    
    ax1.set_title("Original Image : Contains 16,777,256 colors")
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax1.imshow(input_img)
    
    ax2.set_title("Compressed Image : Contains "+ str(k)+ " colors : ")
    ax2.set_xticks([])
    ax2.set_yticks([])
    ax2.imshow(compressed_image)
    
    # As the title and the image will be ovelapped so we need to set some offset.
    plt.subplots_adjust(top=0.85)
    
    plt.show()
    
    io.imsave("compressed"+str(Image),compressed_image)
    
    print("Original Image Size : "+str(os.path.getsize(img_dir+Image) / 1000)+" KB \t\t\t\t\t Compressed Image Size : "+str(os.path.getsize("compressed"+str(Image))/1000) +" KB")
    print()
# Out:
# interactive(children=(Dropdown(description='Image', options=('2.jpg', '3.jpg', '1.jpg'), value='2.jpg'), IntSl…
